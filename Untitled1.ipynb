# %%
import requests
import streamlit as st
import pandas as pd
import json

# %%
response = requests.get(f"http://localhost:8000/users")
df = response.text

# %%
pd.DataFrame(json.loads(df))
# Out:
#    id           token     username           email first_name  \
# 0   1  Ggz8SwbrcBp4pQ       Hermas  Hermas@xyz.com       احمد
# 1   2  hpYv1rkDUtWt2w       test11          test11       اجمد
# 2   3  jppqgsE7qYm8PA       sdfsdf          sdfsdf
# 3   4  ap093MnVqGQ6Vg       testtt         testttt
# 4   5  eIpjKwOGRPYc2g        asdas          asdasd       احمد
# 5   6  72WcNPVzmzzY_g   testtttttt           testt       احمد
# 6   7  LnOVnXrLNIImiw     tesytesy       tesytsety       احمد
# 7   8  zcLTttWpEHmZJQ  ahmedhermas    hermashermas       احمد
#
#              last_name          address            city  match  action
# 0     هير ماس احمد على  عمارات الاو قاف  امبابه  الجيزه   True    True
# 1  مجدى عبدالعظيم عباس         ع ش دياب  الهرم - الجيزه  False   False
# 2                                                        False   False
# 3                                                        False   False
# 4     هير ماس احمد على  عمارات الاو قاف  امبابه  الجيزه   True   False
# ...
